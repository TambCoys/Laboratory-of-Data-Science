# %%
import json
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans, HDBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.preprocessing import StandardScaler

# %%
# 1. Carica tracks.json
with open('tracks_cleaned.json', encoding='utf-8') as f:
    tracks = json.load(f)
df_tracks = pd.DataFrame(tracks)

# %% [markdown]
# ## Hierarcical

# %%
def get_linkage_matrix(model):
    # Create linkage matrix 
    
    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    return linkage_matrix

def plot_dendrogram(model, **kwargs):
    linkage_matrix = get_linkage_matrix(model)
    dendrogram(linkage_matrix, **kwargs)

# %%
df_train = df_tracks.drop(['id', 'id_artist', 'title', 'featured_artists', 'primary_artist',
       'language', 'album', 'swear_IT', 'swear_EN', 'swear_IT_words',
       'swear_EN_words', 'year', 'month', 'day', 'n_sentences', 'n_tokens',
       'char_per_tok', 'avg_token_per_clause', #'bpm', 'rolloff', 'flux', 'rms',
       #'flatness', 'spectral_complexity', 'pitch', 'loudness', 
       'album_name', 'album_release_date', 'album_type', 'disc_number', 'track_number',
       'duration_ms', 'explicit', 'popularity', 'id_album', 'lyrics',
       'streams@1month'], axis=1)
scaler = StandardScaler()
scaler.fit(df_train)
df_train_2 = scaler.transform(df_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44544\217156011.py in ?()
#       6        'album_name', 'album_release_date', 'album_type', 'disc_number', 'track_number',
#       7        'duration_ms', 'explicit', 'popularity', 'id_album', 'lyrics',
#       8        'streams@1month'], axis=1)
#       9 scaler = StandardScaler()
# ---> 10 scaler.fit(df_train)
#      11 df_train_2 = scaler.transform(df_train)
#
# ~\anaconda3\envs\Progetto_ùLaboratory_of_Data_Science\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     903             Fitted scaler.
#     904         """
#     905         # Reset internal state before fitting
#     906         self._reset()
# --> 907         return self.partial_fit(X, y, sample_weight)
#
# ~\anaconda3\envs\Progetto_ùLaboratory_of_Data_Science\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\envs\Progetto_ùLaboratory_of_Data_Science\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     939         self : object
#     940             Fitted scaler.
#     941         """
#     942         first_call = not hasattr(self, "n_samples_seen_")
# --> 943         X = validate_data(
#     944             self,
#     945             X,
#     946             accept_sparse=("csr", "csc"),
#
# ~\anaconda3\envs\Progetto_ùLaboratory_of_Data_Science\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2950             out = y
#    2951         else:
#    2952             out = X, y
#    2953     elif not no_val_X and no_val_y:
# -> 2954         out = check_array(X, input_name="X", **check_params)
#    2955     elif no_val_X and not no_val_y:
#    2956         out = _check_y(y, **check_params)
#    2957     else:
#
# ~\anaconda3\envs\Progetto_ùLaboratory_of_Data_Science\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050                         )
#    1051                     array = xp.astype(array, dtype, copy=False)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#    1056                     "Complex data not supported\n{}\n".format(array)
#    1057                 ) from complex_warning
#
# ~\anaconda3\envs\Progetto_ùLaboratory_of_Data_Science\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     753         # Use NumPy API to support order
#     754         if copy is True:
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#     759         # At this point array is a NumPy ndarray. We convert it to an array
#     760         # container that is consistent with the input's namespace.
#
# ~\anaconda3\envs\Progetto_ùLaboratory_of_Data_Science\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: 'Spring'

# %% [markdown]
# The commented attributes are the ones that have been left in order to perform the clustering.

# %%
model_2 = AgglomerativeClustering(distance_threshold=10,
                                n_clusters=None, metric='euclidean', linkage='complete')
model_2 = model_2.fit(df_train_2)
plt.title("Hierarchical Clustering Dendrogram - Complete LINK")
plot_dendrogram(model_2, truncate_mode="lastp", color_threshold=10)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %% [markdown]
# Single and average link struggled to separate the songs, while complete link manages to do so better. But several clusters are very small, so not the best for categorizing the songs.

# %% [markdown]
# ## HDBSCAN

# %%
hdb = HDBSCAN(cluster_selection_epsilon=0.5, min_samples=5, 
              min_cluster_size=10, max_cluster_size=15,
              store_centers="centroid")
hdb.fit(df_train_2)
df_tracks['hdbscan_labels'] = hdb.labels_
sns.scatterplot(data=df_tracks, 
                x="pitch",
                y="spectral_complexity", 
                hue=hdb.labels_, 
                style=hdb.labels_, 
                palette="bright")

#plt.scatter(scaler.inverse_transform(hdb.centroids_)[:,0], scaler.inverse_transform(hdb.centroids_)[:,2], c='red', marker='*', s=200)
plt.show()

# %% [markdown]
# Tried several combinations of epsilon and min_samples, but the way the songs are distributed means that there is one big cluster and several very small clusters

# %%
df_tracks = df_tracks.drop(['hdbscan_labels'], axis=1)

# %% [markdown]
# ## K-Means

# %%
# %%time
sse_list = []
sil_list = []

for k in range(2, 60):
    kmeans = KMeans(init='k-means++', n_clusters=k, n_init=10, max_iter=100)
    kmeans.fit(df_train_2)
    sse_list.append(kmeans.inertia_)
    sil_list.append(silhouette_score(df_train_2, kmeans.labels_))
# Out:
# CPU times: total: 6min 35s
# Wall time: 2min 17s

# %%
fig, axs = plt.subplots(2) 

sns.lineplot(x=range(2,len(sse_list)+2), y=sse_list, marker='o', ax=axs[0])
axs[0].set(xlabel='k', ylabel='SSE')

sns.lineplot(x=range(2,len(sil_list)+2), y=sil_list, marker='o', ax=axs[1])
axs[1].set(xlabel='k', ylabel='Silhouette')

plt.tight_layout() # Adjust the padding between and around subplots

# %% [markdown]
# 7 clusters seem to be among the best choice based on SSE and silhouette. 6 clusters would have also been good, but the clusters had fewer attributes which were higher or lower than the mean, making it less clear how to define the categories.

# %%
n_clust = 7
kmeans = KMeans(n_clusters=n_clust, n_init=100, max_iter=100, random_state=42)
kmeans.fit(df_train_2)
# Out:
# KMeans(max_iter=100, n_clusters=7, n_init=100, random_state=42)

# %%
df_tracks['kmeans_labels'] = kmeans.labels_

fig = plt.figure(figsize=(13, 8))

sns.countplot(data=df_tracks, x='kmeans_labels', hue='primary_artist', legend=False)
plt.show()

# %% [markdown]
# Cluster 0: high pitch -> Melodic
#
# Cluster 1: lowest bpm, low rolloff -> Slow Dark
#
# Cluster 2: lowest flatness -> Clean
#
# Cluster 3: lowest rolloff, highest loudness, highest pitch, highest rms -> Warm Bangers
#
# Cluster 4: highest rolloff, high loudness, highest spectral_complexity -> Hype
#
# Cluster 5: low rolloff, lowest loudness, lowest spectral_complexity, lowest rms, lowest flux -> Minimal
#
# Cluster 6: highest bpm, high spectral_complexity -> Fast-Flow

# %%
label_to_cat = {0:'Melodic', 1:'Slow Dark', 2:'Clean', 3:'Warm Bangers', 4:'Hype', 5:'Minimal', 6:'Fast-Flow'}

# %%
for i in range(n_clust):
    df = df_tracks.loc[df_tracks['kmeans_labels']==i, 'category'] = label_to_cat[i]

# %%
df_tracks = df_tracks.drop(['kmeans_labels'], axis=1)
df_tracks
# Out:
#              id    id_artist  \
# 0      TR934808  ART04205421
# 1      TR760029  ART04205421
# 2      TR916821  ART04205421
# 3      TR480968  ART04205421
# 4      TR585039  ART04205421
# ...         ...          ...
# 11161  TR434449  ART02733420
# 11162  TR826351  ART02733420
# 11163  TR529809  ART02733420
# 11164  TR280904  ART02733420
# 11165  TR552777  ART02733420
#
#                                                    title     featured_artists  \
# 0                                           ​polka 2 :-/           Ernia, Guè
# 1                                                  POLKA        Thelonious B.
# 2                                           ​britney ;-)  MamboLosco, RADICAL
# 3                                                    CEO               Taxi B
# 4                                                 LONDRA                Rkomi
# ...                                                  ...                  ...
# 11161  Badabum Cha Cha - Gabri Ponte & Paki Rmx (Radi...                 None
# 11162     Senza Un Posto Nel Mondo - Alternative Version        Tiziano Ferro
# 11163  Badabum Cha Cha - Gabri Ponte & Paki Rmx (Exte...                 None
# 11164                                              Tempo                 None
# 11165                                         Giufa Cafe                 None
#
#       primary_artist language                              album  swear_IT  \
# 0      Rosa Chemical       pl                   FOREVER AND EVER        13
# 1      Rosa Chemical       en                   FOREVER AND EVER         9
# 2      Rosa Chemical       en                   FOREVER AND EVER        16
# 3      Rosa Chemical       it                  OKAY OKAY !! - EP         8
# 4      Rosa Chemical       en                   FOREVER AND EVER         1
# ...              ...      ...                                ...       ...
# 11161      Marracash       it      Badabum Cha Cha (The Remixes)         0
# 11162      Marracash       it  Senza Un Posto Nel Mondo – Single         1
# 11163      Marracash       it      Badabum Cha Cha (The Remixes)         0
# 11164      Marracash       it                             Status         0
# 11165      Marracash       it              Fino A Qui Tutto Bene         0
#
#        swear_EN                                     swear_IT_words  ...  \
# 0             6  ['cazzo', 'cesso', 'coglioni', 'figa', 'merda'...  ...
# 1            12  ['cazzo', 'culo', 'frocio', 'puttana', 'sega',...  ...
# 2            12    ['bastardo', 'cazzo', 'culo', 'merda', 'troia']  ...
# 3             3  ['cazzo', 'culo', 'fottere', 'merda', 'pompino...  ...
# 4             0                                          ['cazzo']  ...
# ...         ...                                                ...  ...
# 11161         0                                                 []  ...
# 11162         0                                        ['fortuna']  ...
# 11163         0                                                 []  ...
# 11164         1                                                 []  ...
# 11165         0                                                 []  ...
#
#       album_type  disc_number  track_number  duration_ms  explicit  \
# 0          album          1.0           3.0     207761.0      True
# 1          album          1.0           3.0     207761.0      True
# 2          album          1.0           1.0     193544.0      True
# 3         single          1.0           2.0     169000.0      True
# 4          album          1.0           8.0     194779.0      True
# ...          ...          ...           ...          ...       ...
# 11161     single          1.0           1.0     234374.0     False
# 11162      album          1.0          20.0     248330.0      True
# 11163     single          1.0           1.0     234374.0     False
# 11164      album          1.0           7.0     302173.0      True
# 11165      album          1.0           6.0     292000.0     False
#
#        popularity   id_album  \
# 0            46.0  ALB115557
# 1            46.0  ALB115557
# 2            39.0  ALB115557
# 3            47.0  ALB730959
# 4            41.0  ALB436151
# ...           ...        ...
# 11161        57.0  ALB248347
# 11162        24.0  ALB100713
# 11163        57.0  ALB248347
# 11164        37.0  ALB100713
# 11165        30.0  ALB412275
#
#                                                   lyrics  streams@1month  \
# 0      Oplà, ah\nBdope, chiama due b—\n\nMi candidere...        186522.0
# 1      Greg Willen, non dormire\n(Brr-poh)\n\nT-T-Tro...        194313.0
# 2      Mothz\nYeah, yeah, yeah-yeah\nBdope, chiama du...         63750.0
# 3      Designer sui vestiti penso di essere un outlet...         41473.0
# 4      Bdope (Yeah)\n\nVuole solo me, non fare la gel...         30553.0
# ...                                                  ...             ...
# 11161  Qui non va, ma questo badabum cha cha\nTira fo...          4663.0
# 11162  Odio questa città (città)\nSappiamo che la ver...          5686.0
# 11163  Qui non va, ma questo badabum cha cha\nTira fo...          5540.0
# 11164  É crudo il suono e questa vibra che ti do\nCru...          4672.0
# 11165  Roccia\nMarracash (Marracash!)\nDedicato per m...          5084.0
#
#            category
# 0           Melodic
# 1              Hype
# 2      Warm Bangers
# 3           Melodic
# 4              Hype
# ...             ...
# 11161  Warm Bangers
# 11162     Fast-Flow
# 11163       Melodic
# 11164  Warm Bangers
# 11165       Minimal
#
# [11166 rows x 38 columns]

# %%
# Convert DataFrame to list of dictionaries
df_tracks_json = df_tracks.to_dict(orient='records')

# Save using your exact formatting style
with open('tracks_cleaned.json', 'w', encoding='utf-8') as f:
    json.dump(df_tracks_json, f, indent=2, ensure_ascii=False)
